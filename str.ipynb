# %% [markdown]
# # what is string

# %% [markdown]
# To record the any text information such as names,words,pharas,sentences and paraghraph or entire encyclopedia
#
# to create the string in single and double quotation

# %%
x='john'
print(x)
# Out:
# john

# %%
type(x)
# Out:
# str

# %% [markdown]
# why we have to prefer double quotation rather than single quotation

# %%
y='john'
print(y)
# Out:
# john

# %%
z='matematical linear algebra & statistics are heart for machine learning and deep learning'
print(z)
# Out:
# matematical linear algebra & statistics are heart for machine learning and deep learning

# %%
p='i'm rajina,i want to become a data scientist.'
print(p)
# Out:
#   Cell In[60], line 1
#     p='i'm rajina,i want to become a data scientist.'
#                                                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
p="i'm rajina,i want to become a data scientist."
print(p)
# Out:
# i'm rajina,i want to become a data scientist.

# %%
q="A paragraph is a self-contained unit of discourse in writing dealing with a particular point or idea. Though not required by the orthographic conventions of any language with a writing system, paragraphs are a conventional means of organizing extended segments of prose.
The sun rises in the east and sets in the west.Every morning, birds sing beautiful songs.Trees provide shade and clean air for everyone.People enjoy walking in the park to relax.Nature brings peace and happiness to all.
# Out:
#   Cell In[53], line 1
#     q="A paragraph is a self-contained unit of discourse in writing dealing with a particular point or idea. Though not required by the orthographic conventions of any language with a writing system, paragraphs are a conventional means of organizing extended segments of prose.
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
q='''A paragraph is a self-contained unit of discourse in writing dealing with a particular point or idea. Though not required by the orthographic conventions of any language with a writing system, paragraphs are a conventional means of organizing extended segments of prose.
The sun rises in the east and sets in the west.Every morning, birds sing beautiful songs.Trees provide shade and clean air for everyone.People enjoy walking in the park to relax.Nature brings peace and happiness to all.'''

# %%
print(q)
# Out:
# A paragraph is a self-contained unit of discourse in writing dealing with a particular point or idea. Though not required by the orthographic conventions of any language with a writing system, paragraphs are a conventional means of organizing extended segments of prose.
# The sun rises in the east and sets in the west.Every morning, birds sing beautiful songs.Trees provide shade and clean air for everyone.People enjoy walking in the park to relax.Nature brings peace and happiness to all.

# %% [markdown]
# # string is immutable

# %%
q.upper()
# Out:
# 'A PARAGRAPH IS A SELF-CONTAINED UNIT OF DISCOURSE IN WRITING DEALING WITH A PARTICULAR POINT OR IDEA. THOUGH NOT REQUIRED BY THE ORTHOGRAPHIC CONVENTIONS OF ANY LANGUAGE WITH A WRITING SYSTEM, PARAGRAPHS ARE A CONVENTIONAL MEANS OF ORGANIZING EXTENDED SEGMENTS OF PROSE.\nTHE SUN RISES IN THE EAST AND SETS IN THE WEST.EVERY MORNING, BIRDS SING BEAUTIFUL SONGS.TREES PROVIDE SHADE AND CLEAN AIR FOR EVERYONE.PEOPLE ENJOY WALKING IN THE PARK TO RELAX.NATURE BRINGS PEACE AND HAPPINESS TO ALL.'

# %%
q
# Out:
# 'A paragraph is a self-contained unit of discourse in writing dealing with a particular point or idea. Though not required by the orthographic conventions of any language with a writing system, paragraphs are a conventional means of organizing extended segments of prose.\nThe sun rises in the east and sets in the west.Every morning, birds sing beautiful songs.Trees provide shade and clean air for everyone.People enjoy walking in the park to relax.Nature brings peace and happiness to all.'

# %% [markdown]
# # list is mutable

# %%
a=[3,5,7,9]

a.append(10)

print(a)
# Out:
# [3, 5, 7, 9, 10]

# %%
a
# Out:
# [3, 5, 7, 9, 10]

# %% [markdown]
# when to use print()

# %%
"ravi"

"aadi"

"pune"
# Out:
# 'pune'

# %%
print("ravi")
print("aadi")
print("pune")
# Out:
# ravi
# aadi
# pune

# %%
print("ravi","aadi", "pune",1,2,4,5,1.5)
# Out:
# ravi aadi pune 1 2 4 5 1.5

# %%
print("ravi","aadi", "pune",1,2,4,5,1.5,True,False,sep=" ")
# Out:
# ravi aadi pune 1 2 4 5 1.5 True False

# %%
print("ravi","aadi", "pune",1,2,4,5,1.5,True,False,sep="CLR")
# Out:
# raviCLRaadiCLRpuneCLR1CLR2CLR4CLR5CLR1.5CLRTrueCLRFalse

# %%
print("ravi","aadi", "pune",1,2,4,5,1.5,True,False,sep="    ")
# Out:
# ravi    aadi    pune    1    2    4    5    1.5    True    False

# %%
print("ravi")
print("ai&ml")
# Out:
# ravi
# ai&ml

# %%
print("ravi",end=" ")
print("ai&ml")
# Out:
# ravi ai&ml

# %%
print("ravi",end="_")
print("ai&ml")
# Out:
# ravi_ai&ml

# %% [markdown]
# cancatenate

# %%
x="ravi"
y="ai&ml"
z="python"

print(x+y+z)
# Out:
# raviai&mlpython

# %%
x=5
y="ravi"

print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 x=5
#       2 y="ravi"
#       3
# ----> 4 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x=5
y="ravi"

print(str(x)+y)
# Out:
# 5ravi

# %% [markdown]
# indexing

# %%
a="datascience"
print(a)
# Out:
# datascience

# %%
print(a[4])
print(a[-7])
# Out:
# s
# s

# %%
print(a[0])
print(a[-0])
# Out:
# d
# d

# %%
print(a[-9])
# Out:
# t

# %%
a="datascience"
print(a)
# Out:
# datascience

# %%
a[0:4]
# Out:
# 'data'

# %%
a[4:7]
# Out:
# 'sci'

# %%
a[:]
# Out:
# 'datascience'

# %%
a[0:11]
# Out:
# 'datascience'

# %%
a[-11:-7]
# Out:
# 'data'

# %%
a[-7:-4]
# Out:
# 'sci'

# %% [markdown]
# +ve slicing with steps

# %%
a="datascience"

a[0:4]
# Out:
# 'data'

# %%
a[0:4:2]
# Out:
# 'dt'

# %%
a[0:4:-2]
# Out:
# ''

# %%
a[0:4:-1]
# Out:
# ''

# %%
a[-11:-7]
# Out:
# 'data'

# %%
a[-11:-7:5]
# Out:
# 'd'

# %%
a[-11:-7:3]
# Out:
# 'da'

# %% [markdown]
# # len

# %%
a="datascience"

# %%
len(a)
# Out:
# 11

# %%
b="rajina"
len(b)
# Out:
# 6

# %% [markdown]
# # index

# %%
b.index("j")
# Out:
# 2

# %%
b.index('a')
# Out:
# 1

# %%
c="arunachala"

c.index("a")
# Out:
# 0

# %%
b.index("r")
# Out:
# 0

# %% [markdown]
# Immutable

# %%
c="Hello"

c
# Out:
# 'Hello'

# %% [markdown]
# # Replace

# %%
c.replace("H","C")
# Out:
# 'Cello'

# %%
c
# Out:
# 'Hello'

# %% [markdown]
# lower()),upper(),capitalized(),title()

# %%
d="mathematical & linear calculus is the heart of machine learning and deep learning"

d
# Out:
# 'mathematical & linear calculus is the heart of machine learning and deep learning'

# %%
d.lower()
# Out:
# 'mathematical & linear calculus is the heart of machine learning and deep learning'

# %%
d.upper()
# Out:
# 'MATHEMATICAL & LINEAR CALCULUS IS THE HEART OF MACHINE LEARNING AND DEEP LEARNING'

# %%
d.capitalize()
# Out:
# 'Mathematical & linear calculus is the heart of machine learning and deep learning'

# %%
d.title()
# Out:
# 'Mathematical & Linear Calculus Is The Heart Of Machine Learning And Deep Learning'

# %% [markdown]
# # count

# %%
e="Deep Neural Network"

# %%
e.count("Ne")
# Out:
# 2

# %%
e.count("e")
# Out:
# 4

# %%
e.count("N")
# Out:
# 2

# %%
e.count("")
# Out:
# 20

# %% [markdown]
# # find

# %%
e.find("D")
# Out:
# 0

# %%
e.find("e")
# Out:
# 1

# %%
e.find("2")
# Out:
# -1

# %% [markdown]
# # startswith/ endswith

# %%
f="it is raining"

# %%
f.startswith("it")
# Out:
# True

# %%
f.startswith("if")
# Out:
# False

# %%
f.endswith("it")
# Out:
# False

# %%
f.endswith("raining")
# Out:
# True

# %% [markdown]
# isalpha/isalnum/isdigit

# %%
g="clr"

# %%
g.isalpha()
# Out:
# True

# %%
g="clr7"
g.isalpha()
# Out:
# False

# %% [markdown]
# # isalnum either string or number or both

# %%
g="clr"
g.isalnum()
# Out:
# True

# %%
i="70"
i.isalnum()
# Out:
# True

# %%
g="clr7"
g.isalnum()
# Out:
# True

# %% [markdown]
# # digit

# %%
j="27"
j.isdigit()
# Out:
# True

# %%
g="clr7" 
g.isdigit()
# Out:
# False

# %% [markdown]
# # split/join

# %%
k="who is pm of india"

k.split()
# Out:
# ['who', 'is', 'pm', 'of', 'india']

# %%
k.split("v")
# Out:
# ['who is pm of india']

# %%
l=['who','is','pm','of','india']
" ".join(l)
# Out:
# 'who is pm of india'

# %% [markdown]
# # format

# %%
a="rajina"

print(f"this is my name:{a}")
# Out:
# this is my name:rajina

# %%
name="rajina"
age=22
print(f"my name is {name} and my age is {age}")

# %% [markdown]
# 2nd method

# %%
print("hello my name is {} and my age is {}".format('rajina',29))
# Out:
# hello my name is rajina and my age is 29

# %%
print("my name is {0} and my age is {1} ". format('rajina',29))
# Out:
# my name is rajina and my age is 29

# %%
print("my name is {0} and my age is {1} ". format('rajina',29))
# Out:
# my name is rajina and my age is 29
