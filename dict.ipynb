# %% [markdown]
# # dictionary
# . A dict object is constructed by using curly bracket {}
#
# mapping of one to one relationship between key,value paired is called dict.
#
# mapping means collection of object.

# %%
narvel_dict={'name':'thor','weapon':'hammer','place':'asgard','super_heros':['captain_america','spiderma','hulk']}

# %%
print(narvel_dict)
# Out:
# {'name': 'thor', 'weapon': 'hammer', 'place': 'asgard', 'super_heros': ['captain_america', 'spiderma', 'hulk']}

# %%
narvel_dict['name']
# Out:
# 'thor'

# %%
narvel_dict['weapon']
# Out:
# 'hammer'

# %%
narvel_dict['super_heros']
# Out:
# ['captain_america', 'spiderma', 'hulk']

# %% [markdown]
# methods

# %% [markdown]
# keys

# %% [markdown]
# key must be unique

# %% [markdown]
# it returns the list of key in dict object.

# %%
narvel_dict.keys()
# Out:
# dict_keys(['name', 'weapon', 'place', 'super_heros'])
